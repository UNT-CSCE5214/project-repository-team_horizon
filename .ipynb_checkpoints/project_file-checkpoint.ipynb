# 714  150.649994
#
# [715 rows x 1 columns]

# %%
df = df.drop(['Date','Adj Close'],axis = 1)
df.head()
# Out:
#         High        Low       Open      Close       Volume
# 0  75.150002  73.797501  74.059998  75.087502  135480400.0
# 1  75.144997  74.125000  74.287498  74.357498  146322800.0
# 2  74.989998  73.187500  73.447502  74.949997  118387200.0
# 3  75.224998  74.370003  74.959999  74.597504  108872000.0
# 4  76.110001  74.290001  74.290001  75.797501  132079200.0

# %%
df.rename(columns = {"Date" : "date", "Open" : "open", "High" : "high", "Low" : "low","Close" : "close", "Volume" : "volume", "Currency" : "currency"}, inplace = True)
#renaming the data frame columns to lower case

# %%
df2=df.copy()

# %%
df2.head()
# Out:
#         high        low       open      close       volume
# 0  75.150002  73.797501  74.059998  75.087502  135480400.0
# 1  75.144997  74.125000  74.287498  74.357498  146322800.0
# 2  74.989998  73.187500  73.447502  74.949997  118387200.0
# 3  75.224998  74.370003  74.959999  74.597504  108872000.0
# 4  76.110001  74.290001  74.290001  75.797501  132079200.0

# %%
X = df2.drop(['close'],axis=1)
y = df2['close']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=0)

# %%
X_train.head()
# Out:
#            high         low        open       volume
# 310  121.480003  118.919998  120.349998   94071200.0
# 542  165.119995  160.869995  163.839996   91974200.0
# 17    79.599998   78.047501   78.150002  162234000.0
# 266  139.850006  135.020004  136.279999  114459400.0
# 318  130.389999  128.520004  128.949997   88844600.0

# %%
X_test.head()
# Out:
#            high         low        open       volume
# 339  131.259995  129.479996  130.850006   78973300.0
# 142   94.904999   93.480003   93.709999  121214000.0
# 243  129.580002  128.039993  128.899994   94359800.0
# 236  124.980003  123.089996  124.370003   82225500.0
# 713  154.240005  151.919998  153.160004   97943200.0

# %%
data_training = pd.DataFrame(df['close'][0:int(len(df)*0.70)])
data_testing = pd.DataFrame(df['close'][int(len(df)*0.70):int(len(df))])

# %%
len(X_train)
# Out:
# 572

# %%
len(X_test)
# Out:
# 143

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

# %%
data_training_array = scaler.fit_transform(X_train)

# %%
data_training_array
# Out:
# array([[0.49503466, 0.50950382, 0.50200771, 0.13766491],
#        [0.85393829, 0.85468605, 0.85839548, 0.13222536],
#        [0.1506055 , 0.1731877 , 0.15619112, 0.31447693],
#        ...,
#        [0.63945137, 0.64724763, 0.63058261, 0.07795284],
#        [0.88930233, 0.88792895, 0.87208063, 0.10513865],
#        [0.79604004, 0.79058671, 0.77284272, 0.1729911 ]])

# %%
X_train.shape
# Out:
# (572, 4)
